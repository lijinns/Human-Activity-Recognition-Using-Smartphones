# %%
import pandas as pd
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.manifold import TSNE
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold 
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.feature_selection import f_classif,SelectKBest,mutual_info_classif
import warnings

# %% [markdown]
# ## Read Dataset

# %%
#Loading the data
train_df = pd.read_csv(r"C:\Users\lijin\Desktop\Sem VI\DSML\proj\train_data.csv")
#train data
trainlabel_df = pd.read_csv(r"C:\Users\lijin\Desktop\Sem VI\DSML\proj\train_labels.csv")
#train labels
test_df = pd.read_csv(r"C:\Users\lijin\Desktop\Sem VI\DSML\proj\test_data.csv")
#test data

# %%
train_df.head(10)
# Out:
#    Unnamed: 0  tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0         356           0.286433          -0.023843          -0.122738
# 1        4482           0.333258          -0.001307          -0.166581
# 2       10012           0.266797          -0.018683          -0.101142
# 3        4386           0.276363          -0.020289          -0.113701
# 4        3751           0.268231          -0.004146          -0.094503
# 5        8432           0.278280          -0.017187          -0.108585
# 6        3399           0.308404          -0.014305          -0.129310
# 7        1932           0.280237          -0.018958          -0.107270
# 8        6822           0.280773          -0.023147          -0.113060
# 9        6205           0.263745          -0.047823          -0.130211
#
#    tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0         -0.915584         -0.710794         -0.880226         -0.932429
# ...

# %%
trainlabel_df.head(10)
# Out:
#    Unnamed: 0            Activity
# 0         356            STANDING
# 1        4482             WALKING
# 2       10012              LAYING
# 3        4386            STANDING
# 4        3751  WALKING_DOWNSTAIRS
# 5        8432             SITTING
# 6        3399  WALKING_DOWNSTAIRS
# 7        1932             SITTING
# 8        6822            STANDING
# 9        6205  WALKING_DOWNSTAIRS

# %%
test_df.head(10)
# Out:
#    Unnamed: 0  tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0        6597           0.238337          -0.039950          -0.158257
# 1        7609           0.125920          -0.027658          -0.050069
# 2       10110           0.281630          -0.012995          -0.082664
# 3        1924           0.276540          -0.014060          -0.101588
# 4        5088           0.286017          -0.017170          -0.122960
# 5        4119           0.299427          -0.011365          -0.100959
# 6        4329           0.516382          -0.005207           0.013008
# 7         513           0.274418          -0.056770          -0.176353
# 8        9182           0.171196          -0.021138          -0.134230
# 9        6987           0.280154          -0.005846          -0.119595
#
#    tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0          0.283615          0.226575         -0.133216          0.244607
# ...

# %%
trainlabel_df['Activity'].value_counts()
# Out:
# LAYING                1525
# STANDING              1514
# SITTING               1440
# WALKING               1382
# WALKING_UPSTAIRS      1241
# WALKING_DOWNSTAIRS    1137
# Name: Activity, dtype: int64

# %% [markdown]
# ## Clean Dataset

# %%
False in train_df[['Unnamed: 0']].values == trainlabel_df[['Unnamed: 0']].values
# Out:
# False

# %% [markdown]
# ###### The first coloumn of the test datset and test label dataset is an identifier and as the order matches for the both. It can be dropped

# %%
train_df = train_df.drop(['Unnamed: 0'],axis = 1)
trainlabel_df = trainlabel_df.drop(['Unnamed: 0'],axis = 1)
test_df = test_df.drop(['Unnamed: 0'],axis = 1)

# %%
print("Total Duplicates Train: {} \n".format(sum(train_df.duplicated())))
print("Total Duplicates in Test: {} \n".format(sum(test_df.duplicated())))
# Out:
# Total Duplicates Train: 0
#
# Total Duplicates in Test: 0

# %%
print("Total Null values in Train: {}\n".format(train_df.isnull().values.sum()))
print("Total Null values in Test: {} \n".format(test_df.isnull().values.sum()))
# Out:
# Total Null values in Train: 0
#
# Total Null values in Test: 0

# %% [markdown]
# ###### There are neither any duplicates nor any null values in any of the datasets

# %%
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Feature Analysis

# %%
#mutual information
mutual_info = mutual_info_classif(train_df,trainlabel_df.values.reshape(-1))

# %%
MI_list =[]
for x in range(len(mutual_info)):
    MI_list.append([train_df.columns[x],mutual_info[x]])
    MI_dict = dict(MI_list)

# %%
MI_dict_sorted = dict(sorted(MI_dict.items(), key=lambda item: item[1]))
MI_dict_sorted
# Out:
# {'subject': 0.0010124919673173416,
#  'tBodyGyroJerk-arCoeff()-Y,4': 0.0032889376961549033,
#  'tBodyGyroJerkMag-arCoeff()3': 0.004878376228911296,
#  'tBodyAccJerkMag-arCoeff()3': 0.010624007759776788,
#  'tBodyGyroJerk-arCoeff()-X,4': 0.014191107634074385,
#  'tBodyAcc-arCoeff()-Y,4': 0.019275627662791894,
#  'tBodyGyroJerk-correlation()-X,Z': 0.02199585849582597,
#  'tBodyAccJerkMag-arCoeff()4': 0.0243066184613272,
#  'tBodyGyroMag-arCoeff()3': 0.02541163930799062,
#  'tBodyGyroMag-arCoeff()4': 0.0278811358029194,
#  'tBodyGyro-arCoeff()-X,3': 0.028036245074151367,
#  'tBodyAccJerk-arCoeff()-Y,4': 0.02808640484196845,
#  'tBodyAccJerk-arCoeff()-X,2': 0.028877759655830726,
#  'tBodyGyroJerk-arCoeff()-Y,3': 0.03016377485997701,
#  'tBodyAccJerk-arCoeff()-Y,3': 0.03311051369404572,
#  'tBodyGyroJerk-arCoeff()-X,3': 0.03313383379259527,
#  'tBodyGyroJerk-correlation()-X,Y': 0.03337406225129724,
#  'tBodyAccJerk-arCoeff()-Y,2': 0.03459182205309119,
# ...

# %% [markdown]
# ###### The features 'tBodyGyroJerk-arCoeff()-Y,4' , 'subject' and 'tBodyGyroJerkMag-arCoeff()3' got relatively low (<0.01) MI values. Therefore, they are dropped.

# %%
train_df = train_df.drop([ 'tBodyGyroJerk-arCoeff()-Y,4','subject','tBodyGyroJerkMag-arCoeff()3' ],axis = 1)
test_df = test_df.drop([ 'tBodyGyroJerk-arCoeff()-Y,4','subject','tBodyGyroJerkMag-arCoeff()3' ],axis = 1)

# %%
for key in [ 'tBodyGyroJerk-arCoeff()-Y,4','subject','tBodyGyroJerkMag-arCoeff()3' ]:
    MI_dict_sorted.pop(key)

# %% [markdown]
# ###### And the dataset is sorted by decreasing MI value of features as to select best N features directly.

# %%
sorted_features = list(MI_dict_sorted.keys())[::-1]

# %%
train_df = train_df[sorted_features]
test_df = test_df[sorted_features]

# %% [markdown]
# ## Training Models

# %% [markdown]
# ### Functions used

# %%
# defines the parameter tuning guidelines
def param_tuning(model,params,num):
    k = num 
    kf = KFold(n_splits=k, random_state=1, shuffle = True)
    grid_search = GridSearchCV(estimator=model, param_grid=params, n_jobs=-1, cv=kf, scoring='f1_micro',error_score=0)
    return grid_search

# %%
# calls the model and defines the parameters to be tuned for each model.
def classifier(modelname):
    if modelname == 'lr':
        model = LogisticRegression()
        params = {
            'penalty' : ['l1', 'l2'],
            'C': np.arange(10,61,10)}
    elif modelname == 'lsvm':
        model = LinearSVC(tol = 0.00005)
        params = {
            'C': np.arange(1,12,2),}
    elif modelname == 'svm':
        model = SVC(kernel = 'rbf')
        params = {
            'C':[2,4,8,16], 
            'gamma':[0.125, 0.250, 0.5, 1]}
    elif modelname == 'dt':
        model = DecisionTreeClassifier()
        params = {
            'max_depth':np.arange(2,10,2)}
    elif modelname == 'rf':
        model = RandomForestClassifier()
        params = {
            'n_estimators': np.arange(20,101,10), 
            'max_depth':np.arange(2,16,2)}
    return model,params

# %%
# defines model, parameters to be tuned and parameter tuning guidelines by model name.
def return_model(modelname):
    model,params = classifier(modelname)
    grid_search = param_tuning(model,params,10)
    return grid_search

# %%
# returns the train_data set with N best features
def feature_selection(train_df,selected_features):
    new_train_df = train_df.iloc[:,:selected_features]
    return new_train_df

# %%
# calculates and returns precision, recall, accuracy and f-measure values
def report(y_test,pred):
    accuracy = accuracy_score(y_test, pred)
    fmeasure = f1_score(y_test,pred,average = 'macro')
    precision = precision_score(y_test,pred,average = 'macro')
    recall = recall_score(y_test,pred,average = 'macro')
    print("Accuracy :", accuracy,'\n')
    print("Precision :", precision,'\n')
    print("Recall :", recall,'\n')
    print("F-measure :", fmeasure,'\n')
    report = classification_report(y_test, pred,digits = 4)
    print(report)
    return accuracy,precision,recall,fmeasure

# %%
# main function
Training_Results = []
def fit_model(modelname,selected_features = 559):
    grid_search = return_model(modelname)
    new_train_df = feature_selection(train_df,selected_features)
    X_train, X_test, y_train, y_test = train_test_split(new_train_df, trainlabel_df, test_size=0.2, random_state=42)
    grid_search.fit(X_train, y_train.values.reshape(-1))
    pred = grid_search.predict(X_test)
    accuracy,precision,recall,fmeasure = report(y_test,pred)
    Training_Results.append([modelname,selected_features,precision,recall,fmeasure])

# %% [markdown]
# ### Logistic Regression

# %%
#100 features
fit_model(modelname = 'lr',selected_features = 100)
# Out:
# Accuracy : 0.9344660194174758
#
# Precision : 0.9393453409388561
#
# Recall : 0.9389252501677144
#
# F-measure : 0.9385394017503033
#
#                     precision    recall  f1-score   support
#
#             LAYING     0.9968    1.0000    0.9984       308
#            SITTING     0.8986    0.8185    0.8567       314
#           STANDING     0.8318    0.9052    0.8670       306
#            WALKING     0.9648    0.9763    0.9705       253
# WALKING_DOWNSTAIRS     0.9726    0.9816    0.9771       217
#   WALKING_UPSTAIRS     0.9714    0.9520    0.9616       250
#
#           accuracy                         0.9345      1648
#          macro avg     0.9393    0.9389    0.9385      1648
#       weighted avg     0.9355    0.9345    0.9343      1648

# %%
#200 features
fit_model(modelname = 'lr',selected_features = 200)
# Out:
# Accuracy : 0.9581310679611651
#
# Precision : 0.9600223804630552
#
# Recall : 0.9602867255232068
#
# F-measure : 0.9599532901638036
#
#                     precision    recall  f1-score   support
#
#             LAYING     0.9967    0.9935    0.9951       308
#            SITTING     0.9431    0.8981    0.9201       314
#           STANDING     0.9034    0.9477    0.9250       306
#            WALKING     0.9725    0.9802    0.9764       253
# WALKING_DOWNSTAIRS     0.9727    0.9862    0.9794       217
#   WALKING_UPSTAIRS     0.9715    0.9560    0.9637       250
#
#           accuracy                         0.9581      1648
#          macro avg     0.9600    0.9603    0.9600      1648
#       weighted avg     0.9585    0.9581    0.9581      1648

# %%
#300 features
fit_model(modelname = 'lr',selected_features = 300)
# Out:
# Accuracy : 0.9672330097087378
#
# Precision : 0.9686255427430525
#
# Recall : 0.9691247078514301
#
# F-measure : 0.9688461942374138
#
#                     precision    recall  f1-score   support
#
#             LAYING     1.0000    0.9935    0.9967       308
#            SITTING     0.9421    0.9331    0.9376       314
#           STANDING     0.9323    0.9444    0.9383       306
#            WALKING     0.9802    0.9763    0.9782       253
# WALKING_DOWNSTAIRS     0.9774    0.9954    0.9863       217
#   WALKING_UPSTAIRS     0.9798    0.9720    0.9759       250
#
#           accuracy                         0.9672      1648
#          macro avg     0.9686    0.9691    0.9688      1648
#       weighted avg     0.9673    0.9672    0.9672      1648

# %%
#400 features
fit_model(modelname = 'lr',selected_features = 400)
# Out:
# Accuracy : 0.966626213592233
#
# Precision : 0.9687999699745881
#
# Recall : 0.9686772975768507
#
# F-measure : 0.9686081607861795
#
#                     precision    recall  f1-score   support
#
#             LAYING     1.0000    0.9968    0.9984       308
#            SITTING     0.9503    0.9140    0.9318       314
#           STANDING     0.9151    0.9510    0.9327       306
#            WALKING     0.9728    0.9881    0.9804       253
# WALKING_DOWNSTAIRS     0.9907    0.9862    0.9885       217
#   WALKING_UPSTAIRS     0.9839    0.9760    0.9799       250
#
#           accuracy                         0.9666      1648
#          macro avg     0.9688    0.9687    0.9686      1648
#       weighted avg     0.9669    0.9666    0.9666      1648

# %%
#500 features
fit_model(modelname = 'lr',selected_features = 500)
# Out:
# Accuracy : 0.9702669902912622
#
# Precision : 0.971734651409434
#
# Recall : 0.9717594684479115
#
# F-measure : 0.9717358565153725
#
#                     precision    recall  f1-score   support
#
#             LAYING     1.0000    0.9968    0.9984       308
#            SITTING     0.9453    0.9363    0.9408       314
#           STANDING     0.9353    0.9444    0.9398       306
#            WALKING     0.9843    0.9921    0.9882       253
# WALKING_DOWNSTAIRS     0.9815    0.9770    0.9792       217
#   WALKING_UPSTAIRS     0.9840    0.9840    0.9840       250
#
#           accuracy                         0.9703      1648
#          macro avg     0.9717    0.9718    0.9717      1648
#       weighted avg     0.9703    0.9703    0.9703      1648

# %%
#all features
fit_model(modelname = 'lr')
# Out:
# Accuracy : 0.9824029126213593
#
# Precision : 0.984061956772508
#
# Recall : 0.9840477046711475
#
# F-measure : 0.9840540008298796
#
#                     precision    recall  f1-score   support
#
#             LAYING     1.0000    1.0000    1.0000       308
#            SITTING     0.9556    0.9586    0.9571       314
#           STANDING     0.9574    0.9542    0.9558       306
#            WALKING     0.9960    0.9960    0.9960       253
# WALKING_DOWNSTAIRS     0.9954    0.9954    0.9954       217
#   WALKING_UPSTAIRS     1.0000    1.0000    1.0000       250
#
#           accuracy                         0.9824      1648
#          macro avg     0.9841    0.9840    0.9841      1648
#       weighted avg     0.9824    0.9824    0.9824      1648

# %% [markdown]
# ### Linear Support Vector Machine

# %%
#100 features
fit_model(modelname = 'lsvm',selected_features = 100)
# Out:
# Accuracy : 0.941747572815534
#
# Precision : 0.9465056158013915
#
# Recall : 0.9464605528412943
#
# F-measure : 0.945929428785429
#
#                     precision    recall  f1-score   support
#
#             LAYING     1.0000    1.0000    1.0000       308
#            SITTING     0.9059    0.8280    0.8652       314
#           STANDING     0.8404    0.9118    0.8746       306
#            WALKING     0.9842    0.9842    0.9842       253
# WALKING_DOWNSTAIRS     0.9729    0.9908    0.9817       217
#   WALKING_UPSTAIRS     0.9757    0.9640    0.9698       250
#
#           accuracy                         0.9417      1648
#          macro avg     0.9465    0.9465    0.9459      1648
#       weighted avg     0.9427    0.9417    0.9416      1648

# %%
#200 features
fit_model(modelname = 'lsvm',selected_features = 200)
# Out:
# Accuracy : 0.9174757281553398
#
# Precision : 0.9426376108517557
#
# Recall : 0.9262456158562594
#
# F-measure : 0.9225192086078637
#
#                     precision    recall  f1-score   support
#
#             LAYING     0.9872    1.0000    0.9935       308
#            SITTING     0.9947    0.6019    0.7500       314
#           STANDING     0.7160    0.9967    0.8333       306
#            WALKING     0.9844    0.9960    0.9902       253
# WALKING_DOWNSTAIRS     0.9817    0.9908    0.9862       217
#   WALKING_UPSTAIRS     0.9918    0.9720    0.9818       250
#
#           accuracy                         0.9175      1648
#          macro avg     0.9426    0.9262    0.9225      1648
#       weighted avg     0.9378    0.9175    0.9141      1648

# %%
#300 features
fit_model(modelname = 'lsvm',selected_features = 300)
# Out:
# Accuracy : 0.9739077669902912
#
# Precision : 0.9758543226602491
#
# Recall : 0.9759808650442707
#
# F-measure : 0.9757951319600596
#
#                     precision    recall  f1-score   support
#
#             LAYING     1.0000    1.0000    1.0000       308
#            SITTING     0.9603    0.9236    0.9416       314
#           STANDING     0.9245    0.9608    0.9423       306
#            WALKING     0.9921    0.9881    0.9901       253
# WALKING_DOWNSTAIRS     0.9863    0.9954    0.9908       217
#   WALKING_UPSTAIRS     0.9920    0.9880    0.9900       250
#
#           accuracy                         0.9739      1648
#          macro avg     0.9759    0.9760    0.9758      1648
#       weighted avg     0.9742    0.9739    0.9739      1648

# %%
#400 features
fit_model(modelname = 'lsvm',selected_features = 400)
# Out:
# Accuracy : 0.9726941747572816
#
# Precision : 0.9749700343937563
#
# Recall : 0.9750274215295684
#
# F-measure : 0.9748988434957541
#
#                     precision    recall  f1-score   support
#
#             LAYING     1.0000    1.0000    1.0000       308
#            SITTING     0.9538    0.9204    0.9368       314
#           STANDING     0.9211    0.9542    0.9374       306
#            WALKING     0.9921    0.9881    0.9901       253
# WALKING_DOWNSTAIRS     0.9908    0.9954    0.9931       217
#   WALKING_UPSTAIRS     0.9920    0.9920    0.9920       250
#
#           accuracy                         0.9727      1648
#          macro avg     0.9750    0.9750    0.9749      1648
#       weighted avg     0.9729    0.9727    0.9727      1648

# %%
#500 features
fit_model(modelname = 'lsvm',selected_features = 500)
# Out:
# Accuracy : 0.9769417475728155
#
# Precision : 0.9801898875153136
#
# Recall : 0.9797191346460735
#
# F-measure : 0.9795594701425978
#
#                     precision    recall  f1-score   support
#
#             LAYING     1.0000    1.0000    1.0000       308
#            SITTING     0.9726    0.9045    0.9373       314
#           STANDING     0.9085    0.9739    0.9401       306
#            WALKING     1.0000    1.0000    1.0000       253
# WALKING_DOWNSTAIRS     1.0000    1.0000    1.0000       217
#   WALKING_UPSTAIRS     1.0000    1.0000    1.0000       250
#
#           accuracy                         0.9769      1648
#          macro avg     0.9802    0.9797    0.9796      1648
#       weighted avg     0.9778    0.9769    0.9769      1648

# %%
#all features
fit_model(modelname = 'lsvm')
# Out:
# Accuracy : 0.9842233009708737
#
# Precision : 0.986111111111111
#
# Recall : 0.985977547423782
#
# F-measure : 0.9860143743080932
#
#                     precision    recall  f1-score   support
#
#             LAYING     1.0000    1.0000    1.0000       308
#            SITTING     0.9500    0.9682    0.9590       314
#           STANDING     0.9667    0.9477    0.9571       306
#            WALKING     1.0000    1.0000    1.0000       253
# WALKING_DOWNSTAIRS     1.0000    1.0000    1.0000       217
#   WALKING_UPSTAIRS     1.0000    1.0000    1.0000       250
#
#           accuracy                         0.9842      1648
#          macro avg     0.9861    0.9860    0.9860      1648
#       weighted avg     0.9843    0.9842    0.9842      1648

# %% [markdown]
# ### Kernel Support Vector Machine

# %%
#100 features
fit_model(modelname = 'svm',selected_features = 100)
# Out:
# Accuracy : 0.9550970873786407
#
# Precision : 0.9579885120511413
#
# Recall : 0.95947373676805
#
# F-measure : 0.9586134508324005
#
#                     precision    recall  f1-score   support
#
#             LAYING     1.0000    0.9805    0.9902       308
#            SITTING     0.9065    0.8949    0.9006       314
#           STANDING     0.8935    0.9052    0.8994       306
#            WALKING     0.9960    0.9842    0.9901       253
# WALKING_DOWNSTAIRS     0.9559    1.0000    0.9775       217
#   WALKING_UPSTAIRS     0.9960    0.9920    0.9940       250
#
#           accuracy                         0.9551      1648
#          macro avg     0.9580    0.9595    0.9586      1648
#       weighted avg     0.9554    0.9551    0.9551      1648

# %%
#200 features
fit_model(modelname = 'svm',selected_features = 200)
# Out:
# Accuracy : 0.9763349514563107
#
# Precision : 0.9777922405733542
#
# Recall : 0.9785463545280934
#
# F-measure : 0.9781377250299376
#
#                     precision    recall  f1-score   support
#
#             LAYING     1.0000    0.9903    0.9951       308
#            SITTING     0.9548    0.9427    0.9487       314
#           STANDING     0.9419    0.9542    0.9481       306
#            WALKING     0.9921    0.9921    0.9921       253
# WALKING_DOWNSTAIRS     0.9819    1.0000    0.9909       217
#   WALKING_UPSTAIRS     0.9960    0.9920    0.9940       250
#
#           accuracy                         0.9763      1648
#          macro avg     0.9778    0.9785    0.9781      1648
#       weighted avg     0.9764    0.9763    0.9763      1648

# %%
#300 features
fit_model(modelname = 'svm',selected_features = 300)
# Out:
# Accuracy : 0.9805825242718447
#
# Precision : 0.9821163101231593
#
# Recall : 0.9824600447677483
#
# F-measure : 0.9822537855301693
#
#                     precision    recall  f1-score   support
#
#             LAYING     1.0000    0.9968    0.9984       308
#            SITTING     0.9643    0.9459    0.9550       314
#           STANDING     0.9455    0.9641    0.9547       306
#            WALKING     0.9960    0.9921    0.9941       253
# WALKING_DOWNSTAIRS     0.9909    1.0000    0.9954       217
#   WALKING_UPSTAIRS     0.9960    0.9960    0.9960       250
#
#           accuracy                         0.9806      1648
#          macro avg     0.9821    0.9825    0.9823      1648
#       weighted avg     0.9807    0.9806    0.9806      1648

# %%
#400 features
fit_model(modelname = 'svm',selected_features = 400)
# Out:
# Accuracy : 0.9811893203883495
#
# Precision : 0.9816493768980514
#
# Recall : 0.9827997125656402
#
# F-measure : 0.9821674752121181
#
#                     precision    recall  f1-score   support
#
#             LAYING     1.0000    0.9838    0.9918       308
#            SITTING     0.9620    0.9682    0.9651       314
#           STANDING     0.9671    0.9608    0.9639       306
#            WALKING     0.9960    0.9921    0.9941       253
# WALKING_DOWNSTAIRS     0.9688    1.0000    0.9841       217
#   WALKING_UPSTAIRS     0.9960    0.9920    0.9940       250
#
#           accuracy                         0.9812      1648
#          macro avg     0.9816    0.9828    0.9822      1648
#       weighted avg     0.9813    0.9812    0.9812      1648

# %%
#500 features
fit_model(modelname = 'svm',selected_features = 500)
# Out:
# Accuracy : 0.9811893203883495
#
# Precision : 0.9808479324560869
#
# Recall : 0.9828448214859229
#
# F-measure : 0.9817115423548192
#
#                     precision    recall  f1-score   support
#
#             LAYING     1.0000    0.9740    0.9868       308
#            SITTING     0.9743    0.9650    0.9696       314
#           STANDING     0.9674    0.9706    0.9690       306
#            WALKING     1.0000    0.9921    0.9960       253
# WALKING_DOWNSTAIRS     0.9474    0.9954    0.9708       217
#   WALKING_UPSTAIRS     0.9960    1.0000    0.9980       250
#
#           accuracy                         0.9812      1648
#          macro avg     0.9808    0.9828    0.9817      1648
#       weighted avg     0.9815    0.9812    0.9812      1648

# %% [markdown]
# ### Decision Tree

# %%
#100 features
fit_model(modelname = 'dt',selected_features = 100)
# Out:
# Accuracy : 0.9120145631067961
#
# Precision : 0.9113441341495799
#
# Recall : 0.9109953842966895
#
# F-measure : 0.9102393162555235
#
#                     precision    recall  f1-score   support
#
#             LAYING     1.0000    1.0000    1.0000       308
#            SITTING     0.9178    0.8535    0.8845       314
#           STANDING     0.8598    0.9216    0.8896       306
#            WALKING     0.9345    0.8458    0.8880       253
# WALKING_DOWNSTAIRS     0.8805    0.9171    0.8984       217
#   WALKING_UPSTAIRS     0.8755    0.9280    0.9010       250
#
#           accuracy                         0.9120      1648
#          macro avg     0.9113    0.9110    0.9102      1648
#       weighted avg     0.9136    0.9120    0.9119      1648

# %%
#200 features
fit_model(modelname = 'dt',selected_features = 200)
# Out:
# Accuracy : 0.9186893203883495
#
# Precision : 0.918107854486725
#
# Recall : 0.9175557902942707
#
# F-measure : 0.917294721465625
#
#                     precision    recall  f1-score   support
#
#             LAYING     1.0000    1.0000    1.0000       308
#            SITTING     0.9273    0.8535    0.8889       314
#           STANDING     0.8610    0.9314    0.8948       306
#            WALKING     0.9228    0.8972    0.9098       253
# WALKING_DOWNSTAIRS     0.8991    0.9032    0.9011       217
#   WALKING_UPSTAIRS     0.8984    0.9200    0.9091       250
#
#           accuracy                         0.9187      1648
#          macro avg     0.9181    0.9176    0.9173      1648
#       weighted avg     0.9198    0.9187    0.9186      1648

# %%
#300 features
fit_model(modelname = 'dt',selected_features = 300)
# Out:
# Accuracy : 0.9326456310679612
#
# Precision : 0.9319846060750518
#
# Recall : 0.9316613732894811
#
# F-measure : 0.9314531397319491
#
#                     precision    recall  f1-score   support
#
#             LAYING     1.0000    1.0000    1.0000       308
#            SITTING     0.9422    0.8822    0.9112       314
#           STANDING     0.8865    0.9444    0.9146       306
#            WALKING     0.9350    0.9091    0.9218       253
# WALKING_DOWNSTAIRS     0.9220    0.9263    0.9241       217
#   WALKING_UPSTAIRS     0.9062    0.9280    0.9170       250
#
#           accuracy                         0.9326      1648
#          macro avg     0.9320    0.9317    0.9315      1648
#       weighted avg     0.9334    0.9326    0.9326      1648

# %%
#400 features
fit_model(modelname = 'dt',selected_features = 400)
# Out:
# Accuracy : 0.9387135922330098
#
# Precision : 0.9384703044747177
#
# Recall : 0.9386705442873509
#
# F-measure : 0.9381439463656407
#
#                     precision    recall  f1-score   support
#
#             LAYING     1.0000    1.0000    1.0000       308
#            SITTING     0.9456    0.8854    0.9145       314
#           STANDING     0.8896    0.9477    0.9177       306
#            WALKING     0.9506    0.9130    0.9315       253
# WALKING_DOWNSTAIRS     0.9241    0.9539    0.9388       217
#   WALKING_UPSTAIRS     0.9209    0.9320    0.9264       250
#
#           accuracy                         0.9387      1648
#          macro avg     0.9385    0.9387    0.9381      1648
#       weighted avg     0.9396    0.9387    0.9387      1648

# %%
#500 features
fit_model(modelname = 'dt',selected_features = 500)
# Out:
# Accuracy : 0.9265776699029126
#
# Precision : 0.9258220936544862
#
# Recall : 0.9255846645701701
#
# F-measure : 0.9255378704330312
#
#                     precision    recall  f1-score   support
#
#             LAYING     1.0000    1.0000    1.0000       308
#            SITTING     0.9175    0.8854    0.9011       314
#           STANDING     0.8836    0.9183    0.9006       306
#            WALKING     0.9112    0.9328    0.9219       253
# WALKING_DOWNSTAIRS     0.9128    0.9171    0.9149       217
#   WALKING_UPSTAIRS     0.9298    0.9000    0.9146       250
#
#           accuracy                         0.9266      1648
#          macro avg     0.9258    0.9256    0.9255      1648
#       weighted avg     0.9269    0.9266    0.9266      1648

# %%
#all features
fit_model(modelname = 'dt')
# Out:
# Accuracy : 0.9314320388349514
#
# Precision : 0.9297671832395557
#
# Recall : 0.9298907013195042
#
# F-measure : 0.929759733111139
#
#                     precision    recall  f1-score   support
#
#             LAYING     1.0000    1.0000    1.0000       308
#            SITTING     0.9117    0.9204    0.9160       314
#           STANDING     0.9175    0.9085    0.9130       306
#            WALKING     0.9147    0.9328    0.9237       253
# WALKING_DOWNSTAIRS     0.9091    0.9217    0.9153       217
#   WALKING_UPSTAIRS     0.9256    0.8960    0.9106       250
#
#           accuracy                         0.9314      1648
#          macro avg     0.9298    0.9299    0.9298      1648
#       weighted avg     0.9315    0.9314    0.9314      1648

# %% [markdown]
# ### Random Forest Classifier

# %%
#100 features
fit_model(modelname = 'rf',selected_features = 100)
# Out:
# Accuracy : 0.9599514563106796
#
# Precision : 0.9614718382919906
#
# Recall : 0.9618359718413666
#
# F-measure : 0.9613483957762442
#
#                     precision    recall  f1-score   support
#
#             LAYING     1.0000    1.0000    1.0000       308
#            SITTING     0.9495    0.8981    0.9231       314
#           STANDING     0.9009    0.9510    0.9253       306
#            WALKING     0.9839    0.9684    0.9761       253
# WALKING_DOWNSTAIRS     0.9467    0.9816    0.9638       217
#   WALKING_UPSTAIRS     0.9878    0.9720    0.9798       250
#
#           accuracy                         0.9600      1648
#          macro avg     0.9615    0.9618    0.9613      1648
#       weighted avg     0.9606    0.9600    0.9600      1648

# %%
#200 features
fit_model(modelname = 'rf',selected_features = 200)
# Out:
# Accuracy : 0.9696601941747572
#
# Precision : 0.9700614720015208
#
# Recall : 0.9704462999394572
#
# F-measure : 0.9700741523966853
#
#                     precision    recall  f1-score   support
#
#             LAYING     0.9935    1.0000    0.9968       308
#            SITTING     0.9700    0.9268    0.9479       314
#           STANDING     0.9340    0.9706    0.9519       306
#            WALKING     0.9879    0.9684    0.9780       253
# WALKING_DOWNSTAIRS     0.9550    0.9770    0.9658       217
#   WALKING_UPSTAIRS     0.9800    0.9800    0.9800       250
#
#           accuracy                         0.9697      1648
#          macro avg     0.9701    0.9704    0.9701      1648
#       weighted avg     0.9700    0.9697    0.9696      1648

# %%
#300 features
fit_model(modelname = 'rf',selected_features = 300)
# Out:
# Accuracy : 0.9733009708737864
#
# Precision : 0.9740372263492673
#
# Recall : 0.9746965436562515
#
# F-measure : 0.9742656317858686
#
#                     precision    recall  f1-score   support
#
#             LAYING     0.9968    0.9968    0.9968       308
#            SITTING     0.9639    0.9363    0.9499       314
#           STANDING     0.9395    0.9641    0.9516       306
#            WALKING     0.9920    0.9763    0.9841       253
# WALKING_DOWNSTAIRS     0.9641    0.9908    0.9773       217
#   WALKING_UPSTAIRS     0.9880    0.9840    0.9860       250
#
#           accuracy                         0.9733      1648
#          macro avg     0.9740    0.9747    0.9743      1648
#       weighted avg     0.9735    0.9733    0.9733      1648

# %%
#400 features
fit_model(modelname = 'rf',selected_features = 400)
# Out:
# Accuracy : 0.9799757281553398
#
# Precision : 0.9798460905961953
#
# Recall : 0.980357796609737
#
# F-measure : 0.9800347430347429
#
#                     precision    recall  f1-score   support
#
#             LAYING     1.0000    1.0000    1.0000       308
#            SITTING     0.9742    0.9618    0.9679       314
#           STANDING     0.9613    0.9739    0.9675       306
#            WALKING     0.9960    0.9723    0.9840       253
# WALKING_DOWNSTAIRS     0.9596    0.9862    0.9727       217
#   WALKING_UPSTAIRS     0.9880    0.9880    0.9880       250
#
#           accuracy                         0.9800      1648
#          macro avg     0.9798    0.9804    0.9800      1648
#       weighted avg     0.9801    0.9800    0.9800      1648

# %%
#500 features
fit_model(modelname = 'rf',selected_features = 500)
# Out:
# Accuracy : 0.9763349514563107
#
# Precision : 0.9762579386234925
#
# Recall : 0.9767872218069146
#
# F-measure : 0.9763819547344857
#
#                     precision    recall  f1-score   support
#
#             LAYING     1.0000    1.0000    1.0000       308
#            SITTING     0.9770    0.9490    0.9628       314
#           STANDING     0.9492    0.9771    0.9630       306
#            WALKING     0.9959    0.9684    0.9820       253
# WALKING_DOWNSTAIRS     0.9554    0.9862    0.9705       217
#   WALKING_UPSTAIRS     0.9800    0.9800    0.9800       250
#
#           accuracy                         0.9763      1648
#          macro avg     0.9763    0.9768    0.9764      1648
#       weighted avg     0.9767    0.9763    0.9764      1648

# %%
#all features
fit_model(modelname = 'rf')
# Out:
# Accuracy : 0.9757281553398058
#
# Precision : 0.9762699938949938
#
# Recall : 0.9768379310236149
#
# F-measure : 0.9764508521156777
#
#                     precision    recall  f1-score   support
#
#             LAYING     1.0000    1.0000    1.0000       308
#            SITTING     0.9643    0.9459    0.9550       314
#           STANDING     0.9455    0.9641    0.9547       306
#            WALKING     1.0000    0.9723    0.9860       253
# WALKING_DOWNSTAIRS     0.9598    0.9908    0.9751       217
#   WALKING_UPSTAIRS     0.9880    0.9880    0.9880       250
#
#           accuracy                         0.9757      1648
#          macro avg     0.9763    0.9768    0.9765      1648
#       weighted avg     0.9760    0.9757    0.9758      1648

# %% [markdown]
# ## Results

# %%
Results = pd.DataFrame(Training_Results)
Results.columns =['Model','Features','Precision','Recall','Fmeasure']

# %%
Results.sort_values('Fmeasure',ascending = False)
# Out:
#    Model  Features  Precision  Recall  Fmeasure
# 11  lsvm       559     0.9861  0.9860    0.9860
# 5     lr       559     0.9841  0.9840    0.9841
# 14   svm       300     0.9821  0.9825    0.9823
# 15   svm       400     0.9816  0.9828    0.9822
# 16   svm       500     0.9808  0.9828    0.9817
# 26    rf       400     0.9798  0.9804    0.9800
# 10  lsvm       500     0.9802  0.9797    0.9796
# 13   svm       200     0.9778  0.9785    0.9781
# 28    rf       559     0.9763  0.9768    0.9765
# 27    rf       500     0.9763  0.9768    0.9764
# 8   lsvm       300     0.9759  0.9760    0.9758
# 9   lsvm       400     0.9750  0.9750    0.9749
# 25    rf       300     0.9740  0.9747    0.9743
# 4     lr       500     0.9717  0.9718    0.9717
# 24    rf       200     0.9701  0.9704    0.9701
# 2     lr       300     0.9686  0.9691    0.9688
# 3     lr       400     0.9688  0.9687    0.9686
# 23    rf       100     0.9615  0.9618    0.9613
# 1     lr       200     0.9600  0.9603    0.9600
# ...

# %% [markdown]
# #### The Linear SVM model with 559 features gives the best results

# %% [markdown]
# ## Predicting the Test labels

# %%
#calling the model
model = return_model('lsvm')

# %%
#fitting to train data
model.fit(train_df,trainlabel_df.values.reshape(-1))
# Out:
# GridSearchCV(cv=KFold(n_splits=10, random_state=1, shuffle=True), error_score=0,
#              estimator=LinearSVC(tol=5e-05), n_jobs=-1,
#              param_grid={'C': array([ 1,  3,  5,  7,  9, 11])},
#              scoring='f1_micro')

# %%
#predicting the activity
pred = model.predict(test_df)

# %%
#exporting the predictions to a text file
file = open('lijin_ns_test_data_class_labels.txt','w+')
for i in pred:
    file.write(str(i)+'\n')
file.close()

# %% [markdown]
# ## Classification Report

# %%
from sklearn.metrics import classification_report

# %%
path = #Enter csv file path here
y_true = np.array(pd.read_csv(path,header = None)).reshape(-1)

# %%
print(classification_report(y_true, pred))
